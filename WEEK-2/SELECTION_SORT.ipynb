# %% [markdown]
# <a href="https://colab.research.google.com/github/kdhanushkdhanush71-hub/2025-26-4087-Dhanush-AI-B-DS/blob/main/WEEK-2/SELECTION_SORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Selection sort
n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# selection sort logic
for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # swap found min element with first element
    arr[i], arr[min_index] = arr[min_index], arr[i]

print("sorted array:", arr)
# Out:
# enter number of elements:3
# enter element 1:34
# enter element 2:12
# enter element 3:09
#
#  Original array: [34, 12, 9]
# sorted array: [9, 12, 34]
