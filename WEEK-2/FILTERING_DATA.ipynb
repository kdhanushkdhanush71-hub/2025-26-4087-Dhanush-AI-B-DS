# %% [markdown]
# <a href="https://colab.research.google.com/github/kdhanushkdhanush71-hub/2025-26-4087-Dhanush-AI-B-DS/blob/main/WEEK-2/FILTERING_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#filtering data
import pandas as pd
data={
    "ID":[101,102,103,104,105],
    "name":["alice","bob","charlie","david","eva"],
    "age":[22,25,23,24,26],
    "marks":[85,78,92,88,90]
}
df=pd.DataFrame(data)
print("original data:")
print("df")
print("\n students with marks >85:")
print(df[df["marks"]>85])
print("\n students with age <25:")
print(df[df["age"]<25])
print(df[(df["age"]>23)&(df["marks"]>=88)])
# Out:
# original data:
# df
#
#  students with marks >85:
#     ID     name  age  marks
# 2  103  charlie   23     92
# 3  104    david   24     88
# 4  105      eva   26     90
#
#  students with age <25:
#     ID     name  age  marks
# 0  101    alice   22     85
# 2  103  charlie   23     92
# 3  104    david   24     88
#     ID   name  age  marks
# 3  104  david   24     88
# 4  105    eva   26     90
